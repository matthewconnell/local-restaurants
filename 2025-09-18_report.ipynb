# %% [markdown]
# ## Report on local restaurants

# %%
import altair
import pandas

# %% [markdown]
# This report is to summarize the findings of generated data on local restaurants as of September 17, 2025.
